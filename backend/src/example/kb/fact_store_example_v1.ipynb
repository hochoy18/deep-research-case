# %%
from agent.kb import FactStore

milvus_uri = 'localhost:19530'
collection_name = 'deep_research_case'
COLLECTION_NAME = "research_facts"

DEFAULT_EMBEDDING_DIM = 1024
DEFAULT_EMBEDDING_MODEL = "text-embedding-v3"


fact_store = FactStore(
    uri=milvus_uri,
    collection=COLLECTION_NAME,
    embedding_dim=DEFAULT_EMBEDDING_DIM,
    embedding_model=DEFAULT_EMBEDDING_MODEL,
)
fact_store.query()
# Out:
# ---------------------------------------------------------------------------
# ConnectionConfigException                 Traceback (most recent call last)
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/src/agent/kb/fact_store.py:284, in FactStore._ensure_collection(self)
#     283 try:
# --> 284     if self.client.has_collection(self.collection):
#     285         logger.info(f"[KB] collection '{self.collection}' already exists")
#
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/src/agent/kb/fact_store.py:277, in FactStore.client(self)
#     276 if self._client is None:
# --> 277     self._client = MilvusClient(uri=self.uri)
#     278 return self._client
#
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/.venv/lib/python3.11/site-packages/pymilvus/milvus_client/milvus_client.py:91, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      90 kwargs.pop("cluster_id", None)
# ---> 91 self._config = ConnectionConfig.from_uri(
#      92     uri,
#      93     token=final_token,
#      94     db_name=db_name,
#      95     **kwargs,
#      96 )
#      97 self._manager = ConnectionManager.get_instance()
#
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/.venv/lib/python3.11/site-packages/pymilvus/client/connection_manager.py:131, in ConnectionConfig.from_uri(cls, uri, token, db_name, **kwargs)
#     130     all_schemes = "[unix, " + ", ".join(valid_schemes) + "]"
# --> 131     raise ConnectionConfigException(
#     132         message=f"uri: {uri} is illegal, needs start with {all_schemes} "
#     133         f"or a local file endswith [.db]"
#     134     )
#     136 # Extract host:port (default port depends on scheme)
#
# ConnectionConfigException: <ConnectionConfigException: (code=1, message=uri: localhost:19530 is illegal, needs start with [unix, http, https, tcp] or a local file endswith [.db])>
#
# The above exception was the direct cause of the following exception:
#
# KBConnectionError                         Traceback (most recent call last)
# Cell In[1], line 10
#       6 DEFAULT_EMBEDDING_DIM = 1024
#       7 DEFAULT_EMBEDDING_MODEL = "text-embedding-v3"
#       8
#       9
# ---> 10 fact_store = FactStore(
#      11     uri=milvus_uri,
#      12     collection=collection_name,
#      13     embedding_dim=DEFAULT_EMBEDDING_DIM,
#
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/src/agent/kb/fact_store.py:68, in FactStore.__init__(self, uri, collection, embedding_dim, embedding_model)
#      63 self.embedding_model = embedding_model or os.getenv(
#      64     "EMBEDDING_MODEL", DEFAULT_EMBEDDING_MODEL
#      65 )
#      67 self._client: MilvusClient | None = None
# ---> 68 self._ensure_collection()
#
# File ~/Desktop/AI/202607_智泊/Learning/Projects/Deep-Research/zhipo/codes/deep-research-cases/v1/deep-research-case/backend/src/agent/kb/fact_store.py:288, in FactStore._ensure_collection(self)
#     286         return
#     287 except Exception as e:
# --> 288     raise KBConnectionError(
#     289         f"Milvus 连接失败（检查集合是否存在时）: {e}"
#     290     ) from e
#     292 # 创建集合
#     293 try:
#
# KBConnectionError: Milvus 连接失败（检查集合是否存在时）: <ConnectionConfigException: (code=1, message=uri: localhost:19530 is illegal, needs start with [unix, http, https, tcp] or a local file endswith [.db])>
